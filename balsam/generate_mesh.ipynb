# %% [markdown]
# # Converting Images to a Cloud Volume Image Layer
#
# This module demonstrates how to convert a sequence of image files into a CLoudVolume image layer. The images can be in any standard format, including TIFF, PNG, JPEG, BMP, and many more. See the [scikit-image docs](https://scikit-image.org/docs/dev/api/skimage.io.html "skimage.io Documentation") for more information about file types.

# %%
# We need to add balsam and the modules it depends on to the Python search paths. 
import sys
sys.path.insert(0,'/soft/datascience/Balsam/0.3.5.1/env/lib/python3.6/site-packages/')
sys.path.insert(0,'/soft/datascience/Balsam/0.3.5.1/')

# We also need balsam and postgresql to be in the path. (Misha suggests this may not be necessary)
import os
os.environ['PATH'] ='/soft/datascience/Balsam/0.3.5.1/env/bin/:' + os.environ['PATH']
os.environ['PATH'] +=':/soft/datascience/PostgreSQL/9.6.12/bin/'
try:
    import balsam
except ImportError:
    print('Cannot find balsam, make sure balsam is installed or it is available in Python search paths')
    
os.environ["BALSAM_DB_PATH"]='/lus/theta-fs0/projects/connectomics_aesp/balsam_database/'

from balsam_helper import *

# Import widgets
from ipywidgets import interact, interactive
from ipywidgets import fixed, interact_manual 
from ipywidgets import Textarea, widgets, Layout, Accordion
from ipywidgets import VBox, HBox, Box, Text, BoundedIntText

env_preamble = '/lus/theta-fs0/projects/connectomics_aesp/software/HappyNeuron/macros_theta/theta_build_preamble.sh'

# %% [markdown]
# ## Set up the Application
#
# Before submitting image conversion jobs, make sure there is a Balsam application available to you. Here, we set up a HappyNeuron application and img2cv workflow. The application will run the img2cv executable installed with HappyNeuron.

# %%
add_app(
    'HappyNeuron_meshing',
    'python /home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py',  # 'mesh_generator',
    description='Create a 3D segmentation mesh.',
    envscript=env_preamble
)
# Out:
# Created new app
# Application 15:
# -----------------------
# name:                           HappyNeuron_meshing
# description:                    Create a 3D segmentation mesh.
# executable:                     python /home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py
# preprocess:
# envscript:                      /lus/theta-fs0/projects/connectomics_aesp/software/HappyNeuron/macros_theta/theta_build_preamble.sh
# postprocess:

# %% [markdown]
# ## Set up the Workflow and Job
#
# This is where job parameters will be set and added to a workflow in the application.

# %%
seg_path = '/lus/theta-fs0/projects/connectomics_aesp/pipeline_data/generate_mesh/precomputed/segmentation'

args = f'--labels {seg_path}'

job_id = add_job(
    'generate_mesh',  # Job Name
    'generate_mesh_rafcube',   # Workflow Name
    'HappyNeuron_meshing',
    description='Convert the Allen stack to a CloudVolume image layer.',
    args=args,
    num_nodes=2,
    ranks_per_node=4
)

# %% [markdown]
# ## Run the Conversion

# %%
submit(project='connectomics_aesp',
   queue='debug-flat-quad',
   nodes=2,
   wall_minutes=20,
   wf_filter='generate_mesh_rafcube'
)
# Out:
# Submit OK: Qlaunch {   'command': '/lus/theta-fs0/projects/connectomics_aesp/balsam_database/qsubmit/qlaunch98.sh',
#     'from_balsam': True,
#     'id': 98,
#     'job_mode': 'mpi',
#     'nodes': 2,
#     'prescheduled_only': False,
#     'project': 'connectomics_aesp',
#     'queue': 'debug-flat-quad',
#     'scheduler_id': 379875,
#     'state': 'submitted',
#     'wall_minutes': 20,
#     'wf_filter': 'generate_mesh_rafcube'}

# %%
def get_job_info(job_id='',show_output=False):
    """
    Prints verbose job info for a given job id.
    Parameters
    ----------
    job_id: str, Partial or full Balsam job id.
    """
    from balsam.launcher.dag import BalsamJob as Job
    jobs = Job.objects.all().filter(job_id__contains=job_id)
    if len(jobs) == 1:
        thejob = jobs[0]
        print(jobs[0])
        if show_output:
            output = f'{thejob.working_directory}/{thejob.name}.out'
            with open(output) as f:
                out = f.read()
            print(f'Output file {output} content:')
            print(out)
    elif len(jobs) == 0:
        print('No matching jobs')
    else:
        print(f'{len(jobs)} jobs matched, enter full id.')
        
get_job_info(job_id=job_id, show_output=True)
# Out:
# BalsamJob 3af7d6c9-b808-404f-ba6f-894b95329e61
# ----------------------------------------------
# workflow:                       generate_mesh_rafcube
# name:                           generate_mesh
# description:                    Convert the Allen stack to a CloudVolume image layer.
# lock:                           thetamom2:37025
# parents:                        []
# input_files:                    *
# stage_in_url:
# stage_out_files:
# stage_out_url:
# wall_time_minutes:              1
# num_nodes:                      2
# coschedule_num_nodes:           0
# ranks_per_node:                 4
# cpu_affinity:                   depth
# threads_per_rank:               1
# threads_per_core:               1
# node_packing_count:             1
# environ_vars:                   KMP_BLOCKTIME=0:KMP_AFFINITY=granularity=fine,verbose,compact,1,0
# application:                    HappyNeuron_meshing
# args:                           --labels /lus/theta-fs0/projects/connectomics_aesp/pipeline_data/generate_mesh/precomputed/segmentation
# user_workdir:
# wait_for_parents:               True
# post_error_handler:             False
# post_timeout_handler:           False
# auto_timeout_retry:             True
# state:                          RUNNING
# queued_launch_id:               None
# data:                           {}
#   *** Executed command:         python /home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py --labels /lus/theta-fs0/projects/connectomics_aesp/pipeline_data/generate_mesh/precomputed/segmentation
#   *** Working directory:        /lus/theta-fs0/projects/connectomics_aesp/balsam_database/data/generate_mesh_rafcube/generate_mesh_3af7d6c9
#
# Output file /lus/theta-fs0/projects/connectomics_aesp/balsam_database/data/generate_mesh_rafcube/generate_mesh_3af7d6c9/generate_mesh.out content:
# ---------------------------------
# Tensorflow version 1.14.0 + Horovod 0.16.4 loaded
# ModuleCmd_Switch.c(179):ERROR:152: Module 'gcc/7.3.0' is currently not loaded
# 2019-10-17 21:35:13,987 mesh_generator_v3.py Rank 3 : Starting on host nid00011
# 2019-10-17 21:35:13,987 mesh_generator_v3.py Rank 2 : Starting on host nid00011
# 2019-10-17 21:35:13,987 mesh_generator_v3.py Rank 1 : Starting on host nid00011
# 2019-10-17 21:35:13,987 mesh_generator_v3.py Rank 0 : Starting on host nid00011
# 2019-10-17 21:35:13,988 mesh_generator_v3.py Rank 0 : Loading CloudVolume layer at /lus/theta-fs0/projects/connectomics_aesp/pipeline_data/generate_mesh/precomputed/segmentation
# 2019-10-17 21:35:13,991 mesh_generator_v3.py Rank 0 : Meshing volume with dimensions [64, 64, 64]
# 2019-10-17 21:35:13,991 mesh_generator_v3.py Rank 0 : Setting up meshing task queue.
# 2019-10-17 21:35:14,028 mesh_generator_v3.py Rank 6 : Starting on host nid00000
# 2019-10-17 21:35:14,028 mesh_generator_v3.py Rank 7 : Starting on host nid00000
# 2019-10-17 21:35:14,029 mesh_generator_v3.py Rank 5 : Starting on host nid00000
# 2019-10-17 21:35:14,029 mesh_generator_v3.py Rank 4 : Starting on host nid00000
# 2019-10-17 21:35:33,911 mesh_generator_v3.py Rank 0 : 16740 tasks created.
# 2019-10-17 21:35:41,503 mesh_generator_v3.py Rank 2 : Running task queue 1.
# 2019-10-17 21:35:41,533 mesh_generator_v3.py Rank 6 : Running task queue 1.
# 2019-10-17 21:35:41,534 mesh_generator_v3.py Rank 7 : Running task queue 1.
# 2019-10-17 21:35:41,540 mesh_generator_v3.py Rank 4 : Running task queue 1.
# 2019-10-17 21:35:41,549 mesh_generator_v3.py Rank 3 : Running task queue 1.
# 2019-10-17 21:35:41,551 mesh_generator_v3.py Rank 5 : Running task queue 1.
# 2019-10-17 21:35:41,602 mesh_generator_v3.py Rank 0 : Running task queue 1.
# 2019-10-17 21:35:41,612 mesh_generator_v3.py Rank 1 : Running task queue 1.
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 244, in <module>
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 244, in <module>
# Traceback (most recent call last):
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 244, in <module>
#     main()
#     main()
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 240, in main
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 240, in main
#     main()
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 240, in main
# Traceback (most recent call last):
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 244, in <module>
#     generate_mesh(args.labels, dim_size=args.dim_size, quiet=args.quiet)
#     generate_mesh(args.labels, dim_size=args.dim_size, quiet=args.quiet)
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 200, in generate_mesh
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 200, in generate_mesh
#     main()
#     generate_mesh(args.labels, dim_size=args.dim_size, quiet=args.quiet)
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 240, in main
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 200, in generate_mesh
#     mtq.run(sub_ranges[RANK])
#     mtq.run(sub_ranges[RANK])
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 82, in run
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 82, in run
#     generate_mesh(args.labels, dim_size=args.dim_size, quiet=args.quiet)
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 200, in generate_mesh
#     self._queue[i].execute()
#     self._queue[i].execute()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/igneous/tasks/tasks.py", line 330, in execute
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/igneous/tasks/tasks.py", line 330, in execute
#     mtq.run(sub_ranges[RANK])
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 82, in run
#     mtq.run(sub_ranges[RANK])
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 82, in run
#     self._queue[i].execute()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/igneous/tasks/tasks.py", line 330, in execute
#     self._queue[i].execute()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/igneous/tasks/tasks.py", line 330, in execute
# Traceback (most recent call last):
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 244, in <module>
#     main()
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 240, in main
#     generate_mesh(args.labels, dim_size=args.dim_size, quiet=args.quiet)
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 200, in generate_mesh
#     data = self._volume[data_bounds]
#     data = self._volume[data_bounds]
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/frontends/precomputed.py", line 518, in __getitem__
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/frontends/precomputed.py", line 518, in __getitem__
#     data = self._volume[data_bounds]
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/frontends/precomputed.py", line 518, in __getitem__
#     mtq.run(sub_ranges[RANK])
#     data = self._volume[data_bounds]
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/frontends/precomputed.py", line 518, in __getitem__
#   File "/home/kinnison/HappyNeuron/happyneuron/mesh/mesh_generator.py", line 82, in run
#     self._queue[i].execute()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/igneous/tasks/tasks.py", line 330, in execute
#     img = self.download(requested_bbox, self.mip)
#     img = self.download(requested_bbox, self.mip)
#     img = self.download(requested_bbox, self.mip)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/frontends/precomputed.py", line 554, in download
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/frontends/precomputed.py", line 554, in download
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/frontends/precomputed.py", line 554, in download
#     img = self.download(requested_bbox, self.mip)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/frontends/precomputed.py", line 554, in download
#     img = self.image.download(bbox, mip, parallel=parallel)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/__init__.py", line 136, in download
#     img = self.image.download(bbox, mip, parallel=parallel)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/__init__.py", line 136, in download
#     img = self.image.download(bbox, mip, parallel=parallel)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/__init__.py", line 136, in download
#     img = self.image.download(bbox, mip, parallel=parallel)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/__init__.py", line 136, in download
#     data = self._volume[data_bounds]
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/frontends/precomputed.py", line 518, in __getitem__
#     img = self.download(requested_bbox, self.mip)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/frontends/precomputed.py", line 554, in download
#     img = self.image.download(bbox, mip, parallel=parallel)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/__init__.py", line 136, in download
#     green=self.config.green,
#     green=self.config.green,
#     green=self.config.green,
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 139, in download
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 139, in download
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 139, in download
#     green=self.config.green,
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 139, in download
#     green=self.config.green,
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 139, in download
#     green=green
#     green=green
#     green=green
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 291, in download_chunks_threaded
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 291, in download_chunks_threaded
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 291, in download_chunks_threaded
#     green=green
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 291, in download_chunks_threaded
#     green=green
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 291, in download_chunks_threaded
#     green=green,
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 72, in schedule_jobs
#     green=green,
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 72, in schedule_jobs
#     green=green,
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 72, in schedule_jobs
#     green=green,
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 72, in schedule_jobs
#     green=green,
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 72, in schedule_jobs
#     return schedule_threaded_jobs(fns, concurrency, progress, total)
#     return schedule_threaded_jobs(fns, concurrency, progress, total)
#     return schedule_threaded_jobs(fns, concurrency, progress, total)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 19, in schedule_threaded_jobs
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 19, in schedule_threaded_jobs
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 19, in schedule_threaded_jobs
#     return schedule_threaded_jobs(fns, concurrency, progress, total)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 19, in schedule_threaded_jobs
#     return schedule_threaded_jobs(fns, concurrency, progress, total)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 19, in schedule_threaded_jobs
#     tq.put(wrap(fn))
#     tq.put(wrap(fn))
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 257, in __exit__
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 257, in __exit__
#     tq.put(wrap(fn))
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 257, in __exit__
#     tq.put(wrap(fn))
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 257, in __exit__
#     tq.put(wrap(fn))
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 257, in __exit__
#     self.wait(progress=self.with_progress)
#     self.wait(progress=self.with_progress)
#     self.wait(progress=self.with_progress)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 234, in wait
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 234, in wait
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 234, in wait
#     self.wait(progress=self.with_progress)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 234, in wait
#     self.wait(progress=self.with_progress)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 234, in wait
#     self._check_errors()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 191, in _check_errors
#     self._check_errors()
#     self._check_errors()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 191, in _check_errors
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 191, in _check_errors
#     self._check_errors()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 191, in _check_errors
#     raise err
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 153, in _consume_queue
#     raise err
#     raise err
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 153, in _consume_queue
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 153, in _consume_queue
#     self._consume_queue_execution(fn)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 180, in _consume_queue_execution
#     self._check_errors()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 191, in _check_errors
#     raise err
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 153, in _consume_queue
#     self._consume_queue_execution(fn)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 180, in _consume_queue_execution
#     self._consume_queue_execution(fn)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 180, in _consume_queue_execution
#     fn()
#     self._consume_queue_execution(fn)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 14, in wrapped
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 180, in _consume_queue_execution
#     raise err
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 153, in _consume_queue
#     fn()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 14, in wrapped
#     fn()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 14, in wrapped
#     return fn()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 273, in process
#     return fn()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 273, in process
#     fn()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 14, in wrapped
#     self._consume_queue_execution(fn)
#     return fn()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/threaded_queue.py", line 180, in _consume_queue_execution
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 273, in process
#     enable_cache, compress_cache
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 258, in download_chunk
#     enable_cache, compress_cache
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 258, in download_chunk
#     enable_cache, compress_cache
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 258, in download_chunk
#     img3d = decode(meta, filename, content, fill_missing, mip)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 312, in decode
#     img3d = decode(meta, filename, content, fill_missing, mip)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 312, in decode
#     return fn()
#     fn()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/scheduler.py", line 14, in wrapped
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 273, in process
#     img3d = decode(meta, filename, content, fill_missing, mip)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 312, in decode
#     raise EmptyVolumeException(input_bbox)
# cloudvolume.exceptions.EmptyVolumeException: 10_10_10/2048-2112_1408-1472_384-448
#     enable_cache, compress_cache
#     raise EmptyVolumeException(input_bbox)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 258, in download_chunk
# cloudvolume.exceptions.EmptyVolumeException: 10_10_10/3136-3200_1216-1280_320-384
#     raise EmptyVolumeException(input_bbox)
# cloudvolume.exceptions.EmptyVolumeException: 10_10_10/1024-1088_1664-1728_512-576
#     return fn()
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 273, in process
#     img3d = decode(meta, filename, content, fill_missing, mip)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 312, in decode
#     enable_cache, compress_cache
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 258, in download_chunk
#     img3d = decode(meta, filename, content, fill_missing, mip)
#   File "/lus/theta-fs0/projects/connectomics_aesp/software/neuro_env_36/lib/python3.6/site-packages/cloudvolume/datasource/precomputed/image/rx.py", line 312, in decode
#     raise EmptyVolumeException(input_bbox)
# cloudvolume.exceptions.EmptyVolumeException: 10_10_10/128-192_1024-1088_320-384
#     raise EmptyVolumeException(input_bbox)
# cloudvolume.exceptions.EmptyVolumeException: 10_10_10/1088-1152_704-768_256-320
